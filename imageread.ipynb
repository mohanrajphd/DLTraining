# %% [markdown]
# <a href="https://colab.research.google.com/github/mohanrajphd/DLTraining/blob/main/imageread.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2

# %%
# !git clone https://github.com/mohanrajphd/DLTraining.git
# Out:
# Cloning into 'DLTraining'...
# remote: Enumerating objects: 16, done.
# remote: Counting objects: 100% (16/16), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 16 (delta 3), reused 9 (delta 2), pack-reused 0 (from 0)
# Receiving objects: 100% (16/16), 159.85 KiB | 53.28 MiB/s, done.
# Resolving deltas: 100% (3/3), done.

# %%
image =cv2.imread("/content/DLTraining/1.jpg")

# %%
image.shape
# Out:
# (168, 300, 3)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(image)
